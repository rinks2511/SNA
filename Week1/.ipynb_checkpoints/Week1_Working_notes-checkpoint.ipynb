# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#Undirected Graph
plt.figure()

G=nx.Graph()
G.add_edge('A','B')
G.add_edge('B','C')

nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
plt.figure()

#Directed Graph
G=nx.DiGraph()
G.add_edge('B','A')
G.add_edge('B','C')

nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
#Adding weights to the network
G=nx.Graph()
G.add_edge('A','B',weight=6)

plt.figure()
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
G=nx.Graph()
G.add_edge('A','B',sign='+')
G.add_edge('B','C',sign='-')

plt.figure()
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
G=nx.Graph()
G.add_edge('A','B',relation='friend')
G.add_edge('B','C',relation='coworker')
G.add_edge('D','E',relation='family')
G.add_edge('E','I',relation='neighbor')

plt.figure()
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
G=nx.MultiGraph()
G.add_edge('A','B',relation='friend')
G.add_edge('A','B',relation='neighbor')
G.add_edge('G','F',relation='family')
G.add_edge('G','F',relation='coworker')

plt.figure()
nx.draw_networkx(G)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
G=nx.Graph()
G.add_edge('A','B',weight=6,relation='family')
G.add_edge('B','C',weight=13,relation='friend')

# %%
G.edges()
# Out:
# EdgeView([('A', 'B'), ('B', 'C')])

# %%
G.edges(data=True)
# Out:
# EdgeDataView([('A', 'B', {'weight': 6, 'relation': 'family'}), ('B', 'C', {'weight': 13, 'relation': 'friend'})])

# %%
G.edges(data='relation')
# Out:
# EdgeDataView([('A', 'B', 'family'), ('B', 'C', 'friend')])

# %%
G.edge['A']['B']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-79c9ecbf17fe> in <module>
# ----> 1 G.edge['A']['B']
#
# AttributeError: 'Graph' object has no attribute 'edge'

# %%
G.nodes()
# Out:
# NodeView(('A', 'B', 'C'))

# %%
G.nodes(data=True)
# Out:
# NodeDataView({'A': {}, 'B': {}, 'C': {}})

# %%
G.node['A']
# Out:
# {}

# %%
G.add_node('A',role='trader')
G.nodes(data=True)
# Out:
# NodeDataView({'A': {'role': 'trader'}, 'B': {}, 'C': {}})

# %%
G.node['A']
# Out:
# {'role': 'trader'}

# %%
from networkx.algorithms import bipartite
B=nx.Graph()
B.add_nodes_from(['A','B','C','D','E'],bipartite=0)
B.add_nodes_from([1,2,3,4],bipartite=1)
B.add_edges_from([('A',1),('B',1),('C',1),('C',3),('D',2),('E',3),('E',4)])

# %%
bipartite.is_bipartite(B)
# Out:
# True

# %%
B.add_edge('A','B')
bipartite.is_bipartite(B)
# Out:
# False

# %%
B.remove_edge('A','B')
bipartite.is_bipartite(B)
# Out:
# True

# %%
X=set([1,2,3,4])
bipartite.is_bipartite_node_set(B,X)
# Out:
# True

# %%
X=set(['A','B','C','D','E'])
bipartite.is_bipartite_node_set(B,X)
# Out:
# True

# %%
X=set(['A','B','C','D','E',1])
bipartite.is_bipartite_node_set(B,X)
# Out:
# False

# %%
bipartite.sets(B)
# Out:
# ---------------------------------------------------------------------------
# AmbiguousSolution                         Traceback (most recent call last)
# <ipython-input-41-c67e625ad704> in <module>
# ----> 1 bipartite.sets(B)
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/algorithms/bipartite/basic.py in sets(G, top_nodes)
#     204         if not is_connected(G):
#     205             msg = 'Disconnected graph: Ambiguous solution for bipartite sets.'
# --> 206             raise nx.AmbiguousSolution(msg)
#     207         c = color(G)
#     208         X = {n for n, is_top in c.items() if is_top}
#
# AmbiguousSolution: Disconnected graph: Ambiguous solution for bipartite sets.

# %%
B=nx.Graph()
B.add_edges_from([('A',1),('B',1),('C',1),('D',1),
                  ('H',1),('B',2),('C',2),('D',2),('E',2),
                  ('G',2),('E',3),('F',3),('H',3),('J',3),
                  ('E',4),('I',4),('J',4)])

X=set(['A','B','C','D','E','F','G','H','I','J'])

# %%
bipartite.is_bipartite_node_set(B,X)
# Out:
# True

# %%
P=bipartite.projected_graph(B,X)

# %%
X=set([1,2,3,4])
P=bipartite.weighted_projected_graph(B,X)

# %%
plt.figure()
nx.draw_networkx(P)
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">
# /Users/rajeevsinghal/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
def plot_graph(G, weight_name=None):
    '''
    G: a networkx G
    weight_name: name of the attribute for plotting edge weights (if G is weighted)
    '''
    # %matplotlib notebook
    import matplotlib.pyplot as plt
    
    plt.figure()
    pos = nx.spring_layout(G)
    edges = G.edges()
    weights = None
    
    if weight_name:
        weights = [int(G[u][v][weight_name]) for u,v in edges]
        labels = nx.get_edge_attributes(G,weight_name)
        nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
        nx.draw_networkx(G, pos, edges=edges, width=weights);
    else:
        nx.draw_networkx(G, pos, edges=edges);

# %%
plot_graph(P,'weight')
# Out:
# <img src="data:image/png;base64,..." width="639.4444613839378">

# %%
G=nx.Graph()
G.add_edges_from([('A','K'),('A','B'),('B','C'),('B','K'),('C','E'),
('C','F'),('D','E'),('E','F'),('E','H'),('E','I'),('F','G'),('I','J')])

# %%
nx.clustering(G,'F')
# Out:
# 0.3333333333333333

# %%
nx.clustering(G,'A')
# Out:
# 1.0

# %%
nx.clustering(G,'J')
# Out:
# 0

# %%
nx.average_clustering(G)
# Out:
# 0.28181818181818186

# %%
nx.transitivity(G)
# Out:
# 0.2727272727272727

# %%
nx.shortest_path(G,'A','H')
# Out:
# ['A', 'B', 'C', 'E', 'H']

# %%
nx.shortest_path_length(G,'A','H')
# Out:
# 4

# %%
T=nx.bfs_tree(G,'A')

# %%
T.edges()
# Out:
# OutEdgeView([('A', 'K'), ('A', 'B'), ('B', 'C'), ('C', 'E'), ('C', 'F'), ('E', 'D'), ('E', 'H'), ('E', 'I'), ('F', 'G'), ('I', 'J')])

# %%
nx.shortest_path_length(G,'A')
# Out:
# {'A': 0,
#  'K': 1,
#  'B': 1,
#  'C': 2,
#  'E': 3,
#  'F': 3,
#  'D': 4,
#  'H': 4,
#  'I': 4,
#  'G': 4,
#  'J': 5}

# %%
nx.average_shortest_path_length(G)
# Out:
# 2.5272727272727273

# %%
nx.diameter(G)
# Out:
# 5

# %%
nx.eccentricity(G)
# Out:
# {'A': 5,
#  'K': 5,
#  'B': 4,
#  'C': 3,
#  'E': 3,
#  'F': 3,
#  'D': 4,
#  'H': 4,
#  'I': 4,
#  'G': 4,
#  'J': 5}

# %%
nx.radius(G)
# Out:
# 3

# %%
nx.periphery(G)
# Out:
# ['A', 'K', 'J']

# %%
nx.center(G)
# Out:
# ['C', 'E', 'F']
